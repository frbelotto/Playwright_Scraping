# %%
import nest_asyncio

nest_asyncio.apply()

# %%
# %run C:\Users\fabio\OneDrive\Python\Playwright_Scraping\.vscode\Playwright_Amazon.py
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# File ~\OneDrive\Python\Playwright_Scraping\.vscode\Playwright_Amazon.py:39
#      36     return html
#      38 keyword_list = ['red bull']
# ---> 39 resultado =  asyncio.run(run_scrap(keyword_list[0]))
#      40 print (resultado)
#      42 # async def main(keyword : str):
#      43 #     soup = await web_browser_search(keyword)
#      44
#    (...)
#     137 # for item in keyword_list:
#     138 #     asyncio.run(main(item))
#
# File c:\Users\fabio\OneDrive\Python\Playwright_Scraping\.venv\Lib\site-packages\nest_asyncio.py:31, in _patch_asyncio.<locals>.run(main, debug)
#      29 task = asyncio.ensure_future(main)
#      30 try:
# ---> 31     return loop.run_until_complete(task)
#      32 finally:
#      33     if not task.done():
#
# ...
